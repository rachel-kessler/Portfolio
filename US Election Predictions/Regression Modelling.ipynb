# %% [markdown]
# # Stats and Politics Modelling

# %% [markdown]
# ### Rachel Kessler
# #### 10/27/2019

# %% [markdown]
# The purpose of this analysis is to fit linear and logistic regression models to the republican vote shares within the 2008, 2012, and 2016 US elections.
#
# To begin, the data is imported and joined for further use.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
# %matplotlib inline

# %%
df_votes = pd.read_csv('projectdata/votes_clean.csv')
df_data = pd.read_csv('projectdata/data_clean.csv')
df = pd.merge(df_votes, df_data, on='Fips', how='inner')
df.head()
# Out:
#    Democrats 08 (Votes)  Democrats 12 (Votes)  Republicans 08 (Votes)  \
# 0                2598.0                2630.0                  3860.0
# 1                2144.0                2099.0                  3972.0
# 2                1935.0                1845.0                  3916.0
# 3               13191.0               12792.0                  8181.0
# 4                2595.0                2442.0                  5543.0
#
#    Republicans 12 (Votes)  votes16_trumpd  votes16_clintonh   Fips  \
# 0                  3887.0          3967.0            2364.0   5043
# 1                  4263.0          4917.0            1587.0   5087
# 2                  4136.0          4353.0            1544.0  13159
# 3                  9411.0          8153.0           12652.0   8037
# 4                  5214.0          5021.0            1836.0  13091
#
#    Democrats 08 pct  Democrats 12 pct  Democrats 16 pct  ...  \
# 0         40.229173         40.355992         37.340073  ...
# 1         35.055592         32.992770         24.400369  ...
# 2         33.071270         30.847684         26.182805  ...
# 3         61.720943         57.613836         60.812305  ...
# 4         31.887442         31.896552         26.775558  ...
#
#    Children.in.single.parent.households  Adult.smoking  Adult.obesity  \
# 0                                 0.429          0.181          0.323
# 1                                 0.179          0.304          0.328
# 2                                 0.381          0.210          0.298
# 3                                 0.204          0.095          0.132
# 4                                 0.453          0.189          0.358
#
#   Diabetes Sexually.transmitted.infections HIV.prevalence.rate  Uninsured  \
# 0    0.126                           747.3                79.9      0.197
# 1    0.135                           247.2               131.3      0.239
# 2    0.118                           324.1               402.4      0.239
# 3    0.036                           190.9               133.7      0.230
# 4    0.153                           497.9               315.8      0.208
#
#    Unemployment  Violent.crime  Injury.deaths
# 0         0.108         449.02           82.0
# 1         0.053         245.83           96.8
# 2         0.096         205.60           71.6
# 3         0.081         123.88           42.9
# 4         0.115         477.48           79.4
#
# [5 rows x 58 columns]

# %%
df.columns
# Out:
# Index(['Democrats 08 (Votes)', 'Democrats 12 (Votes)',
#        'Republicans 08 (Votes)', 'Republicans 12 (Votes)', 'votes16_trumpd',
#        'votes16_clintonh', 'Fips', 'Democrats 08 pct', 'Democrats 12 pct',
#        'Democrats 16 pct', 'Republicans 08 pct', 'Republicans 12 pct',
#        'Republicans 16 pct', 'State', 'ST', 'County', 'Precincts', 'Votes',
#        'Less Than High School Diploma', 'At Least High School Diploma',
#        'At Least Bachelors's Degree', 'Graduate Degree', 'School Enrollment',
#        'Median Earnings 2010', 'White (Not Latino) Population',
#        'African American Population', 'Native American Population',
#        'Asian American Population', 'Other Race or Races', 'Latino Population',
#        'Children Under 6 Living in Poverty',
#        'Adults 65 and Older Living in Poverty', 'Total Population',
#        'Preschool.Enrollment.Ratio.enrolled.ages.3.and.4',
#        'Poverty.Rate.below.federal.poverty.threshold', 'Gini.Coefficient',
#        'Child.Poverty.living.in.families.below.the.poverty.line',
#        'Management.professional.and.related.occupations',
#        'Service.occupations', 'Sales.and.office.occupations',
#        'Farming.fishing.and.forestry.occupations',
#        'Construction.extraction.maintenance.and.repair.occupations',
#        'Production.transportation.and.material.moving.occupations',
#        'White_Asian', 'SIRE_homogeneity', 'median_age', 'Low.birthweight',
#        'Teen.births', 'Children.in.single.parent.households', 'Adult.smoking',
#        'Adult.obesity', 'Diabetes', 'Sexually.transmitted.infections',
#        'HIV.prevalence.rate', 'Uninsured', 'Unemployment', 'Violent.crime',
#        'Injury.deaths'],
#       dtype='object')

# %% [markdown]
# # 2008 Republican Vote Share - Linear Regression
# The first step taken was to develop a baseline model to compare others to using all available demographic features in the datasest.
#
# ### Baseline Linear Regression Model

# %%
X_all_cols = ['Less Than High School Diploma', 'At Least High School Diploma',
       "At Least Bachelors's Degree", 'Graduate Degree', 'School Enrollment',
       'Median Earnings 2010', 'White (Not Latino) Population',
       'African American Population', 'Native American Population',
       'Asian American Population', 'Other Race or Races', 'Latino Population',
       'Children Under 6 Living in Poverty',
       'Adults 65 and Older Living in Poverty', 'Total Population',
       'Preschool.Enrollment.Ratio.enrolled.ages.3.and.4',
       'Poverty.Rate.below.federal.poverty.threshold', 'Gini.Coefficient',
       'Child.Poverty.living.in.families.below.the.poverty.line',
       'Management.professional.and.related.occupations',
       'Service.occupations', 'Sales.and.office.occupations',
       'Farming.fishing.and.forestry.occupations',
       'Construction.extraction.maintenance.and.repair.occupations',
       'Production.transportation.and.material.moving.occupations',
       'White_Asian', 'SIRE_homogeneity', 'median_age', 'Low.birthweight',
       'Teen.births', 'Children.in.single.parent.households', 'Adult.smoking',
       'Adult.obesity', 'Diabetes', 'Sexually.transmitted.infections',
       'HIV.prevalence.rate', 'Uninsured', 'Unemployment', 'Violent.crime',
       'Injury.deaths']

# %% [markdown]
# Outputs and inputs are initialized for the base model:

# %%
X = sm.add_constant(df.loc[:,X_all_cols])
y_2008 = df['Republicans 08 pct']

# %% [markdown]
# And the statsmodels linear regression is run.

# %%
lr_2008 = sm.OLS(y_2008,X)
lr_2008_results = lr_2008.fit()
lr_2008_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Republicans 08 pct   R-squared:                       0.677
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     164.7
# Date:                Thu, 24 Oct 2019   Prob (F-statistic):               0.00
# Time:                        15:36:54   Log-Likelihood:                -10869.
# No. Observations:                3109   AIC:                         2.182e+04
# Df Residuals:                    3069   BIC:                         2.206e+04
# Df Model:                          39
# Covariance Type:            nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                        173.0897    410.551      0.422      0.673    -631.893     978.072
# Less Than High School Diploma                                 -0.0004      0.091     -0.004      0.997      -0.180       0.179
# At Least High School Diploma                                   0.0301      0.085      0.354      0.723      -0.137       0.197
# At Least Bachelors's Degree                                   -0.2331      0.068     -3.445      0.001      -0.366      -0.100
# Graduate Degree                                               -0.7490      0.115     -6.508      0.000      -0.975      -0.523
# School Enrollment                                              0.0953      0.037      2.582      0.010       0.023       0.168
# Median Earnings 2010                                       -4.164e-05   5.71e-05     -0.729      0.466      -0.000    7.03e-05
# White (Not Latino) Population                                  0.2167      0.992      0.218      0.827      -1.729       2.163
# African American Population                                   -0.7250      2.974     -0.244      0.807      -6.556       5.106
# Native American Population                                    -0.8407      2.974     -0.283      0.777      -6.672       4.991
# Asian American Population                                     -0.5524      0.993     -0.556      0.578      -2.499       1.394
# Other Race or Races                                           -1.0035      2.979     -0.337      0.736      -6.844       4.837
# Latino Population                                             -0.6730      2.975     -0.226      0.821      -6.505       5.159
# Children Under 6 Living in Poverty                            -0.0384      0.028     -1.369      0.171      -0.093       0.017
# Adults 65 and Older Living in Poverty                          0.0511      0.047      1.081      0.280      -0.042       0.144
# Total Population                                            -2.53e-06   5.71e-07     -4.431      0.000   -3.65e-06   -1.41e-06
# Preschool.Enrollment.Ratio.enrolled.ages.3.and.4              -0.0100      0.011     -0.872      0.383      -0.032       0.012
# Poverty.Rate.below.federal.poverty.threshold                  -0.5005      0.099     -5.077      0.000      -0.694      -0.307
# Gini.Coefficient                                              13.9146      5.999      2.319      0.020       2.152      25.677
# Child.Poverty.living.in.families.below.the.poverty.line        0.1509      0.058      2.592      0.010       0.037       0.265
# Management.professional.and.related.occupations               -0.3686      2.855     -0.129      0.897      -5.967       5.230
# Service.occupations                                           -1.0014      2.855     -0.351      0.726      -6.600       4.597
# Sales.and.office.occupations                                  -0.5917      2.854     -0.207      0.836      -6.188       5.004
# Farming.fishing.and.forestry.occupations                      -0.3832      2.855     -0.134      0.893      -5.981       5.215
# Construction.extraction.maintenance.and.repair.occupations    -0.4641      2.855     -0.163      0.871      -6.061       5.133
# Production.transportation.and.material.moving.occupations     -0.9328      2.855     -0.327      0.744      -6.530       4.665
# White_Asian                                                   -0.3357      1.983     -0.169      0.866      -4.223       3.552
# SIRE_homogeneity                                             -31.7670      1.918    -16.559      0.000     -35.529     -28.005
# median_age                                                    -0.6466      0.050    -12.899      0.000      -0.745      -0.548
# Low.birthweight                                               48.1016     12.199      3.943      0.000      24.182      72.021
# Teen.births                                                    0.1532      0.016      9.832      0.000       0.123       0.184
# Children.in.single.parent.households                         -27.0996      2.708    -10.007      0.000     -32.409     -21.790
# Adult.smoking                                                -12.9433      3.344     -3.871      0.000     -19.500      -6.387
# Adult.obesity                                                 -9.3364      6.477     -1.441      0.150     -22.036       3.363
# Diabetes                                                     156.4249     13.806     11.330      0.000     129.355     183.495
# Sexually.transmitted.infections                               -0.0044      0.001     -3.750      0.000      -0.007      -0.002
# HIV.prevalence.rate                                           -0.0024      0.001     -2.491      0.013      -0.004      -0.001
# Uninsured                                                     86.7369      4.988     17.391      0.000      76.958      96.516
# Unemployment                                                 -77.8155      7.127    -10.919      0.000     -91.789     -63.842
# Violent.crime                                                 -0.0013      0.001     -1.328      0.184      -0.003       0.001
# Injury.deaths                                                  0.0138      0.009      1.487      0.137      -0.004       0.032
# ==============================================================================
# Omnibus:                       18.560   Durbin-Watson:                   1.831
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.648
# Skew:                          -0.156   Prob(JB):                     5.41e-05
# Kurtosis:                       3.232   Cond. No.                     1.08e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.85e-18. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# An initial review of the baseline model shows an adjusted R squared value of 0.673. This is the primary metric used to compare models. The baseline model also shows about 50% of variables with p-values above the accepted 0.05 level as well as many standard errors that are large with respect to the coefficient. A look at the variance inflation factors takes place next in order to identify instances of multicollinearity.

# %%
pd.Series([variance_inflation_factor(X.values, i) 
               for i in range(X.shape[1])], 
              index=X.columns)
# Out:
# C:\Users\rache\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:185: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# const                                                         8.120962e+06
# Less Than High School Diploma                                 2.163465e+01
# At Least High School Diploma                                  1.952314e+01
# At Least Bachelors's Degree                                   1.652498e+01
# Graduate Degree                                               9.482443e+00
# School Enrollment                                             1.656250e+00
# Median Earnings 2010                                          3.979842e+00
# White (Not Latino) Population                                          inf
# African American Population                                   8.876530e+04
# Native American Population                                    1.594125e+04
# Asian American Population                                              inf
# Other Race or Races                                           9.529918e+02
# Latino Population                                             7.213810e+04
# Children Under 6 Living in Poverty                            5.324335e+00
# Adults 65 and Older Living in Poverty                         3.175262e+00
# Total Population                                              1.533962e+00
# Preschool.Enrollment.Ratio.enrolled.ages.3.and.4              1.300104e+00
# Poverty.Rate.below.federal.poverty.threshold                  1.882782e+01
# Gini.Coefficient                                              2.305754e+00
# Child.Poverty.living.in.families.below.the.poverty.line       1.485855e+01
# Management.professional.and.related.occupations               1.606007e+04
# Service.occupations                                           4.794463e+03
# Sales.and.office.occupations                                  4.711762e+03
# Farming.fishing.and.forestry.occupations                      2.638928e+03
# Construction.extraction.maintenance.and.repair.occupations    4.431838e+03
# Production.transportation.and.material.moving.occupations     1.407394e+04
# White_Asian                                                            inf
# SIRE_homogeneity                                              6.023561e+00
# median_age                                                    2.849899e+00
# Low.birthweight                                               2.955321e+00
# Teen.births                                                   4.515372e+00
# Children.in.single.parent.households                          3.736492e+00
# Adult.smoking                                                 1.804597e+00
# Adult.obesity                                                 3.646873e+00
# Diabetes                                                      4.594701e+00
# Sexually.transmitted.infections                               4.076868e+00
# HIV.prevalence.rate                                           1.825529e+00
# Uninsured                                                     3.500981e+00
# Unemployment                                                  1.851118e+00
# Violent.crime                                                 1.828758e+00
# Injury.deaths                                                 2.100205e+00
# dtype: float64

# %% [markdown]
# The test for multicollinearity resulted in a couple infinity values which will need to be removed from the selected model. Overall, the baseline model could definitely be improved.

# %% [markdown]
# ## Key Model Selection Parameters (in order of significance):
# * An adjusted R-Squared equivalent to or slightly lower than 0.673
# * Fewer input variables (ideally 15-20)
# * Statistically significant p-vales (below 0.05)
# * Standard errors which are significantly lower than coefficients
# * VIFs lower than the baseline model

# %% [markdown]
# ### Alternate Model 1: Backwards (Manual/EDA Based) Selection:
#
# Alternate Model 1 was developed by utilizing knowledge gained from the prior exploratory data analyis through knowledge of highly correlated columns. The model contains 20 input features (any less would have resulted in large drops in the adjusted R squared):

# %%
X_cols = [
        'Graduate Degree', 
       'White (Not Latino) Population', 'African American Population',
        'Latino Population',
        'Total Population',
       'Poverty.Rate.below.federal.poverty.threshold', 
       'Service.occupations', 'Sales.and.office.occupations',
       'Production.transportation.and.material.moving.occupations',
        'SIRE_homogeneity', 'median_age', 'Low.birthweight',
       'Teen.births', 'Children.in.single.parent.households', 'Adult.smoking',
       'Diabetes', 'Sexually.transmitted.infections',
       'Uninsured', 'Unemployment'
       ]

# %%
X = sm.add_constant(df.loc[:,X_cols])
lr_2008 = sm.OLS(y_2008,X)
lr_2008_results = lr_2008.fit()
lr_2008_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Republicans 08 pct   R-squared:                       0.672
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                     332.7
# Date:                Thu, 24 Oct 2019   Prob (F-statistic):               0.00
# Time:                        15:48:09   Log-Likelihood:                -10892.
# No. Observations:                3109   AIC:                         2.182e+04
# Df Residuals:                    3089   BIC:                         2.195e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# =============================================================================================================================
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# const                                                        50.0087      3.452     14.486      0.000      43.240      56.778
# Graduate Degree                                              -1.0470      0.056    -18.634      0.000      -1.157      -0.937
# White (Not Latino) Population                                 0.7385      0.030     24.768      0.000       0.680       0.797
# African American Population                                   0.1021      0.028      3.691      0.000       0.048       0.156
# Latino Population                                             0.1917      0.028      6.897      0.000       0.137       0.246
# Total Population                                          -2.854e-06   5.21e-07     -5.482      0.000   -3.87e-06   -1.83e-06
# Poverty.Rate.below.federal.poverty.threshold                 -0.2337      0.041     -5.642      0.000      -0.315      -0.152
# Service.occupations                                          -0.6249      0.051    -12.173      0.000      -0.726      -0.524
# Sales.and.office.occupations                                 -0.2190      0.050     -4.388      0.000      -0.317      -0.121
# Production.transportation.and.material.moving.occupations    -0.5055      0.037    -13.630      0.000      -0.578      -0.433
# SIRE_homogeneity                                            -30.3547      1.792    -16.940      0.000     -33.868     -26.841
# median_age                                                   -0.5629      0.042    -13.422      0.000      -0.645      -0.481
# Low.birthweight                                              53.0160     11.835      4.480      0.000      29.810      76.222
# Teen.births                                                   0.1504      0.014     10.666      0.000       0.123       0.178
# Children.in.single.parent.households                        -26.1076      2.607    -10.016      0.000     -31.218     -20.997
# Adult.smoking                                               -13.1618      3.254     -4.045      0.000     -19.541      -6.782
# Diabetes                                                    163.0012     11.120     14.658      0.000     141.198     184.804
# Sexually.transmitted.infections                              -0.0044      0.001     -4.079      0.000      -0.006      -0.002
# Uninsured                                                    88.1121      4.348     20.266      0.000      79.588      96.637
# Unemployment                                                -76.0650      6.684    -11.380      0.000     -89.171     -62.959
# ==============================================================================
# Omnibus:                       22.229   Durbin-Watson:                   1.830
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.592
# Skew:                          -0.175   Prob(JB):                     7.53e-06
# Kurtosis:                       3.246   Cond. No.                     2.70e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.7e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
pd.Series([variance_inflation_factor(X.values, i) 
               for i in range(X.shape[1])], 
              index=X.columns)
# Out:
# const                                                        569.357651
# Graduate Degree                                                2.241269
# White (Not Latino) Population                                 15.807848
# African American Population                                    7.620395
# Latino Population                                              6.246043
# Total Population                                               1.264644
# Poverty.Rate.below.federal.poverty.threshold                   3.295278
# Service.occupations                                            1.536813
# Sales.and.office.occupations                                   1.429364
# Production.transportation.and.material.moving.occupations      2.354563
# SIRE_homogeneity                                               5.210829
# median_age                                                     1.977866
# Low.birthweight                                                2.757939
# Teen.births                                                    3.668708
# Children.in.single.parent.households                           3.432791
# Adult.smoking                                                  1.693873
# Diabetes                                                       2.955416
# Sexually.transmitted.infections                                3.415186
# Uninsured                                                      2.637739
# Unemployment                                                   1.614511
# dtype: float64

# %% [markdown]
# ### Alternate Model 2: Forwards (Automated) Selection -
# #### This Model was Selected as Best Performing (Explanation Below)
# Alternate Model 2 was developed by looping through all the possible columns and building the features one by one based off of the highest adjusted R squared value:

# %%
X_all_cols = ['Less Than High School Diploma', 'At Least High School Diploma',
       "At Least Bachelors's Degree", 'Graduate Degree', 'School Enrollment',
       'Median Earnings 2010', 'White (Not Latino) Population',
       'African American Population', 'Native American Population',
       'Asian American Population', 'Other Race or Races', 'Latino Population',
       'Children Under 6 Living in Poverty',
       'Adults 65 and Older Living in Poverty', 'Total Population',
       'Preschool.Enrollment.Ratio.enrolled.ages.3.and.4',
       'Poverty.Rate.below.federal.poverty.threshold', 'Gini.Coefficient',
       'Child.Poverty.living.in.families.below.the.poverty.line',
       'Management.professional.and.related.occupations',
       'Service.occupations', 'Sales.and.office.occupations',
       'Farming.fishing.and.forestry.occupations',
       'Construction.extraction.maintenance.and.repair.occupations',
       'Production.transportation.and.material.moving.occupations',
       'White_Asian', 'SIRE_homogeneity', 'median_age', 'Low.birthweight',
       'Teen.births', 'Children.in.single.parent.households', 'Adult.smoking',
       'Adult.obesity', 'Diabetes', 'Sexually.transmitted.infections',
       'HIV.prevalence.rate', 'Uninsured', 'Unemployment', 'Violent.crime',
       'Injury.deaths']

# %%
y_2008 = df['Republicans 08 pct']
X_current_cols = []
r_sq = 0

# %% [markdown]
# The for loop starts with checking one feature at a time, and based off of the highest adjusted R squared value, the best feature is added to the list of input features. The while loop repeats this until the features reaches the selected length of 30. The while loop prints out the adjusted R squared at each step so that an optimal number of features can be selected.

# %%
while len(X_current_cols)<30:
    for i in range(len(X_all_cols)):
        X_cols = X_current_cols + [X_all_cols[i]]
        X = sm.add_constant(df.loc[:,X_cols])
        lr_2008 = sm.OLS(y_2008,X)
        lr_2008_results = lr_2008.fit()
        if lr_2008_results.rsquared_adj > r_sq:
            r_sq = lr_2008_results.rsquared_adj
            best_col = [X_all_cols[i]]
    X_current_cols += best_col
    print(str(len(X_current_cols))+' R-squared: '+str(r_sq))
# Out:
# 1 R-squared: 0.1364488321948507
# 2 R-squared: 0.3072746189243768
# 3 R-squared: 0.4056782063373514
# 4 R-squared: 0.4932887664590744
# 5 R-squared: 0.5511554226465762
# 6 R-squared: 0.5788571625191299
# 7 R-squared: 0.6010600299073643
# 8 R-squared: 0.6163280613625386
# 9 R-squared: 0.6276954342456587
# 10 R-squared: 0.6382279277925292
# 11 R-squared: 0.647823459499283
# 12 R-squared: 0.6527056154328533
# 13 R-squared: 0.6568153212592872
# 14 R-squared: 0.6597686775051594
# 15 R-squared: 0.6620235492431579
# 16 R-squared: 0.664327419062045
# 17 R-squared: 0.6660168723014877
# 18 R-squared: 0.6671626937478206
# 19 R-squared: 0.668153751229476
# 20 R-squared: 0.6693632271064307
# 21 R-squared: 0.6704332307105534
# 22 R-squared: 0.6711142996506869
# 23 R-squared: 0.6716908645921109
# 24 R-squared: 0.6721226684244954
# 25 R-squared: 0.672398233533061
# 26 R-squared: 0.6725175871709103
# 27 R-squared: 0.6726511580658392
# 28 R-squared: 0.6728014754208331
# 29 R-squared: 0.6729182725947163
# 30 R-squared: 0.673022860723558

# %% [markdown]
# According to the printout above, the model reaches an adjusted R squared of approximately 0.7 at 20 features. This will be selected to compare to alternate 1. The summary and VIF were calculated below:

# %%
X_current_cols = X_current_cols[0:20]
X_current_cols
# Out:
# ['Graduate Degree',
#  'Children.in.single.parent.households',
#  'Uninsured',
#  'White (Not Latino) Population',
#  'SIRE_homogeneity',
#  'Unemployment',
#  'Teen.births',
#  'Service.occupations',
#  'Diabetes',
#  'Production.transportation.and.material.moving.occupations',
#  'median_age',
#  'Native American Population',
#  'Total Population',
#  'Sexually.transmitted.infections',
#  'Poverty.Rate.below.federal.poverty.threshold',
#  'Other Race or Races',
#  'Sales.and.office.occupations',
#  'School Enrollment',
#  'Low.birthweight',
#  'Adult.smoking']

# %%
X = sm.add_constant(df.loc[:,X_current_cols])
lr_2008 = sm.OLS(y_2008,X)
lr_2008_results = lr_2008.fit()
lr_2008_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Republicans 08 pct   R-squared:                       0.671
# Model:                            OLS   Adj. R-squared:                  0.669
# Method:                 Least Squares   F-statistic:                     315.6
# Date:                Thu, 24 Oct 2019   Prob (F-statistic):               0.00
# Time:                        16:11:33   Log-Likelihood:                -10894.
# No. Observations:                3109   AIC:                         2.183e+04
# Df Residuals:                    3088   BIC:                         2.196e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# =============================================================================================================================
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# const                                                        57.7278      4.107     14.056      0.000      49.675      65.781
# Graduate Degree                                              -1.0811      0.057    -18.897      0.000      -1.193      -0.969
# Children.in.single.parent.households                        -27.6746      2.564    -10.793      0.000     -32.702     -22.647
# Uninsured                                                    92.8037      4.212     22.031      0.000      84.544     101.063
# White (Not Latino) Population                                 0.5797      0.019     31.247      0.000       0.543       0.616
# SIRE_homogeneity                                            -29.7381      1.790    -16.616      0.000     -33.247     -26.229
# Unemployment                                                -77.5380      6.680    -11.608      0.000     -90.636     -64.440
# Teen.births                                                   0.1786      0.014     12.964      0.000       0.152       0.206
# Service.occupations                                          -0.5852      0.052    -11.285      0.000      -0.687      -0.484
# Diabetes                                                    143.7431     10.158     14.150      0.000     123.826     163.661
# Production.transportation.and.material.moving.occupations    -0.5032      0.037    -13.496      0.000      -0.576      -0.430
# median_age                                                   -0.5465      0.042    -12.993      0.000      -0.629      -0.464
# Native American Population                                   -0.1087      0.029     -3.794      0.000      -0.165      -0.053
# Total Population                                           -2.92e-06   5.19e-07     -5.627      0.000   -3.94e-06    -1.9e-06
# Sexually.transmitted.infections                              -0.0060      0.001     -6.050      0.000      -0.008      -0.004
# Poverty.Rate.below.federal.poverty.threshold                 -0.2431      0.041     -5.864      0.000      -0.324      -0.162
# Other Race or Races                                          -0.4183      0.109     -3.829      0.000      -0.633      -0.204
# Sales.and.office.occupations                                 -0.1937      0.050     -3.857      0.000      -0.292      -0.095
# School Enrollment                                             0.1059      0.034      3.136      0.002       0.040       0.172
# Low.birthweight                                              39.4722     11.097      3.557      0.000      17.715      61.230
# Adult.smoking                                               -11.3735      3.243     -3.507      0.000     -17.732      -5.015
# ==============================================================================
# Omnibus:                       21.237   Durbin-Watson:                   1.821
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.736
# Skew:                          -0.166   Prob(JB):                     1.16e-05
# Kurtosis:                       3.255   Cond. No.                     2.70e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.7e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
pd.Series([variance_inflation_factor(X.values, i) 
               for i in range(X.shape[1])], 
              index=X.columns)
# Out:
# const                                                        804.869998
# Graduate Degree                                                2.321124
# Children.in.single.parent.households                           3.317721
# Uninsured                                                      2.473250
# White (Not Latino) Population                                  6.112236
# SIRE_homogeneity                                               5.192051
# Unemployment                                                   1.610587
# Teen.births                                                    3.495551
# Service.occupations                                            1.566401
# Diabetes                                                       2.463430
# Production.transportation.and.material.moving.occupations      2.377564
# median_age                                                     1.987302
# Native American Population                                     1.464609
# Total Population                                               1.255487
# Sexually.transmitted.infections                                2.913877
# Poverty.Rate.below.federal.poverty.threshold                   3.295198
# Other Race or Races                                            1.269467
# Sales.and.office.occupations                                   1.445330
# School Enrollment                                              1.374174
# Low.birthweight                                                2.421607
# Adult.smoking                                                  1.680894
# dtype: float64

# %% [markdown]
# ### Comparison of Linear Regression Models:
# Models were compared on the basis of the key model selection parameters listed above:
# * An adjusted R-Squared equivalent to or slightly lower than 0.673:
#     * **Alt 1: 0.670**
#     * **Alt 2: 0.669**
# * Fewer input variables (ideally 15-20)
#     * **Both have 20 inputs**
# * VIFs lower than the baseline model
#     * **Alternate 1 has double the VIF for White (Not Latino) Population than Alternate 2**
# * Statistically significant p-vales (below 0.05)
#     * **Both have p-values below 0.05 (almost all close to 0.000)**
# * Standard errors which are significantly lower than coefficients
#     * **Both have reasonable standard errors**

# %% [markdown]
# VIF was the deciding factor in the model selection (as the other factors were nearly the same), so **ALTERNATE MODEL 2** was selected.

# %% [markdown]
# ### Model Interpretation
#
# The selected model had the following inputs as independent variables:
#
# Graduate Degree, Children.in.single.parent.households, Uninsured, White (Not Latino) Population, SIRE_homogeneity, Unemployment, Teen.births, Service.occupations, Diabetes, Production.transportation.and.material.moving.occupations, median_age, Native American Population, Total Population, Sexually.transmitted.infections, Poverty.Rate.below.federal.poverty.threshold, Other Race or Races, Sales.and.office.occupations, School Enrollment, Low.birthweight, Adult.smoking
#
# Many of these variables were correlated with the republican vote share in the exploratory data analysis.
#
# Because the units vary, coefficients cannot be compared directly; however, the sign of the coefficient gives explanation into which way the feature influences the dependent variable (i.e. as diabetes increases, republican vote share increases, and as graduate degrees increase, the republican vote share decreases).
#
# Units of some coefficients are inferred - such as median age (in years). This coefficient can then be interpreted directly: with every 1 year increase in median age, republican vote share is expected to decrease by 0.54.

# %% [markdown]
# # 2008 Republican Vote Share - Logistic Regression
# The next step taken was to develop a baseline model to compare others to using all available demographic features in the datasest.
#
# ### Baseline Logistic Regression Model

# %%
y_2008 = df['Republicans 08 pct']/100
y_2008_binary = np.where(y_2008>0.5,1,0)
total = len(y_2008)

# %%
X_all_cols = ['Less Than High School Diploma', 'At Least High School Diploma',
       "At Least Bachelors's Degree", 'Graduate Degree', 'School Enrollment',
       'Median Earnings 2010', 'White (Not Latino) Population',
       'African American Population', 'Native American Population',
       'Asian American Population', 'Other Race or Races', 'Latino Population',
       'Children Under 6 Living in Poverty',
       'Adults 65 and Older Living in Poverty', 'Total Population',
       'Preschool.Enrollment.Ratio.enrolled.ages.3.and.4',
       'Poverty.Rate.below.federal.poverty.threshold', 'Gini.Coefficient',
       'Child.Poverty.living.in.families.below.the.poverty.line',
       'Management.professional.and.related.occupations',
       'Service.occupations', 'Sales.and.office.occupations',
       'Farming.fishing.and.forestry.occupations',
       'Construction.extraction.maintenance.and.repair.occupations',
       'Production.transportation.and.material.moving.occupations',
       'White_Asian', 'SIRE_homogeneity', 'median_age', 'Low.birthweight',
       'Teen.births', 'Children.in.single.parent.households', 'Adult.smoking',
       'Adult.obesity', 'Diabetes', 'Sexually.transmitted.infections',
       'HIV.prevalence.rate', 'Uninsured', 'Unemployment', 'Violent.crime',
       'Injury.deaths']

# %%
X = sm.add_constant(df.loc[:,X_all_cols])
logr_2008 = sm.Logit(y_2008,X)
logr_2008_results = logr_2008.fit()
logr_2008_results.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.619129
#          Iterations: 35
# C:\Users\rache\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\rache\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:1286: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
# C:\Users\rache\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\rache\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\rache\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1831: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:     Republicans 08 pct   No. Observations:                 3109
# Model:                          Logit   Df Residuals:                     3069
# Method:                           MLE   Df Model:                           39
# Date:                Thu, 24 Oct 2019   Pseudo R-squ.:                 -0.1008
# Time:                        16:40:13   Log-Likelihood:                -1924.9
# converged:                      False   LL-Null:                       -1748.6
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          4.5002    106.225      0.042      0.966    -203.697     212.697
# Less Than High School Diploma                                  0.0005      0.027      0.019      0.985      -0.052       0.053
# At Least High School Diploma                                   0.0016      0.025      0.062      0.950      -0.048       0.051
# At Least Bachelors's Degree                                   -0.0108      0.018     -0.613      0.540      -0.046       0.024
# Graduate Degree                                               -0.0315      0.030     -1.045      0.296      -0.091       0.028
# School Enrollment                                              0.0045      0.010      0.461      0.645      -0.015       0.024
# Median Earnings 2010                                       -1.795e-06   1.49e-05     -0.120      0.904   -3.11e-05    2.75e-05
# White (Not Latino) Population                                  0.0133        nan        nan        nan         nan         nan
# African American Population                                   -0.0220      0.769     -0.029      0.977      -1.529       1.485
# Native American Population                                    -0.0282      0.769     -0.037      0.971      -1.536       1.479
# Asian American Population                                     -0.0221        nan        nan        nan         nan         nan
# Other Race or Races                                           -0.0352      0.770     -0.046      0.964      -1.545       1.475
# Latino Population                                             -0.0199      0.769     -0.026      0.979      -1.528       1.488
# Children Under 6 Living in Poverty                            -0.0016      0.007     -0.217      0.828      -0.016       0.013
# Adults 65 and Older Living in Poverty                          0.0018      0.012      0.142      0.887      -0.023       0.026
# Total Population                                            -1.14e-07   1.64e-07     -0.694      0.488   -4.36e-07    2.08e-07
# Preschool.Enrollment.Ratio.enrolled.ages.3.and.4              -0.0004      0.003     -0.139      0.889      -0.006       0.005
# Poverty.Rate.below.federal.poverty.threshold                  -0.0223      0.026     -0.868      0.385      -0.073       0.028
# Gini.Coefficient                                               0.6553      1.585      0.414      0.679      -2.451       3.761
# Child.Poverty.living.in.families.below.the.poverty.line        0.0067      0.015      0.440      0.660      -0.023       0.037
# Management.professional.and.related.occupations               -0.0160      0.740     -0.022      0.983      -1.467       1.435
# Service.occupations                                           -0.0450      0.740     -0.061      0.952      -1.496       1.406
# Sales.and.office.occupations                                  -0.0277      0.740     -0.037      0.970      -1.478       1.423
# Farming.fishing.and.forestry.occupations                      -0.0158      0.740     -0.021      0.983      -1.467       1.435
# Construction.extraction.maintenance.and.repair.occupations    -0.0215      0.740     -0.029      0.977      -1.472       1.429
# Production.transportation.and.material.moving.occupations     -0.0422      0.740     -0.057      0.955      -1.493       1.409
# White_Asian                                                   -0.0088        nan        nan        nan         nan         nan
# SIRE_homogeneity                                              -1.4416      0.522     -2.760      0.006      -2.465      -0.418
# median_age                                                    -0.0285      0.013     -2.160      0.031      -0.054      -0.003
# Low.birthweight                                                2.0767      3.169      0.655      0.512      -4.135       8.288
# Teen.births                                                    0.0066      0.004      1.612      0.107      -0.001       0.015
# Children.in.single.parent.households                          -1.1822      0.711     -1.663      0.096      -2.576       0.211
# Adult.smoking                                                 -0.5669      0.872     -0.650      0.516      -2.277       1.143
# Adult.obesity                                                 -0.4171      1.687     -0.247      0.805      -3.723       2.889
# Diabetes                                                       6.6828      3.617      1.848      0.065      -0.407      13.772
# Sexually.transmitted.infections                               -0.0002      0.000     -0.653      0.514      -0.001       0.000
# HIV.prevalence.rate                                           -0.0001      0.000     -0.476      0.634      -0.001       0.000
# Uninsured                                                      3.8092      1.323      2.880      0.004       1.217       6.402
# Unemployment                                                  -3.3117      1.858     -1.782      0.075      -6.954       0.330
# Violent.crime                                              -4.549e-05      0.000     -0.181      0.857      -0.001       0.000
# Injury.deaths                                                  0.0005      0.002      0.218      0.827      -0.004       0.005
# ==============================================================================================================================
# """

# %%
model_predictions_prob = logr_2008_results.predict(X)
model_predictions_binary = np.where(model_predictions_prob>0.5,1,0)
correct = (model_predictions_binary == y_2008_binary).sum()
correct/total
# Out:
# 0.8404631714377614

# %% [markdown]
# An initial review of the baseline model shows an accuracy of 84% This is the primary metric used to compare models. The baseline model also shows about 75% of variables with p-values above the accepted 0.05 level as well as many standard errors that are large with respect to the coefficient.

# %% [markdown]
# ## Key Model Selection Parameters (in order of significance):
# * An accuracy equivalent to or slightly lower than 0.84
# * Fewer input variables (ideally 5-20)
# * Lower VIFs
# * Statistically significant p-values (below 0.05)
# * Standard errors which are significantly lower than coefficients

# %% [markdown]
# ### Alternate Model 1: Manual Selection
#
# Alternate Model 1 was developed by utilizing the variables from the previous linear regression model. The model contains 20 input features.

# %%
X_cols = ['Graduate Degree',
 'Children.in.single.parent.households',
 'Uninsured',
 'White (Not Latino) Population',
 'SIRE_homogeneity',
 'Unemployment',
 'Teen.births',
 'Service.occupations',
 'Diabetes',
 'Production.transportation.and.material.moving.occupations',
 'median_age',
 'Native American Population',
 'Total Population',
 'Sexually.transmitted.infections',
 'Poverty.Rate.below.federal.poverty.threshold',
 'Other Race or Races',
 'Sales.and.office.occupations',
 'School Enrollment',
 'Low.birthweight',
 'Adult.smoking']

# %%
X = sm.add_constant(df.loc[:,X_cols])
logr_2008 = sm.Logit(y_2008,X)
logr_2008_results = logr_2008.fit()
logr_2008_results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.619532
#          Iterations 5
# C:\Users\rache\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:     Republicans 08 pct   No. Observations:                 3109
# Model:                          Logit   Df Residuals:                     3088
# Method:                           MLE   Df Model:                           20
# Date:                Thu, 24 Oct 2019   Pseudo R-squ.:                 -0.1015
# Time:                        16:59:32   Log-Likelihood:                -1926.1
# converged:                       True   LL-Null:                       -1748.6
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# =============================================================================================================================
#                                                                 coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# const                                                         0.4007      1.084      0.370      0.712      -1.724       2.526
# Graduate Degree                                              -0.0468      0.015     -3.120      0.002      -0.076      -0.017
# Children.in.single.parent.households                         -1.1952      0.671     -1.782      0.075      -2.510       0.119
# Uninsured                                                     4.0663      1.107      3.674      0.000       1.897       6.236
# White (Not Latino) Population                                 0.0255      0.005      5.078      0.000       0.016       0.035
# SIRE_homogeneity                                             -1.3520      0.484     -2.795      0.005      -2.300      -0.404
# Unemployment                                                 -3.2904      1.735     -1.897      0.058      -6.690       0.110
# Teen.births                                                   0.0078      0.004      2.164      0.030       0.001       0.015
# Service.occupations                                          -0.0266      0.014     -1.944      0.052      -0.054       0.000
# Diabetes                                                      6.1537      2.638      2.333      0.020       0.984      11.324
# Production.transportation.and.material.moving.occupations    -0.0232      0.010     -2.357      0.018      -0.042      -0.004
# median_age                                                   -0.0239      0.011     -2.180      0.029      -0.045      -0.002
# Native American Population                                   -0.0058      0.008     -0.731      0.465      -0.021       0.010
# Total Population                                          -1.356e-07    1.5e-07     -0.907      0.365   -4.29e-07    1.58e-07
# Sexually.transmitted.infections                              -0.0003      0.000     -1.006      0.314      -0.001       0.000
# Poverty.Rate.below.federal.poverty.threshold                 -0.0106      0.011     -0.982      0.326      -0.032       0.011
# Other Race or Races                                          -0.0197      0.031     -0.634      0.526      -0.081       0.041
# Sales.and.office.occupations                                 -0.0103      0.013     -0.769      0.442      -0.037       0.016
# School Enrollment                                             0.0051      0.009      0.574      0.566      -0.012       0.023
# Low.birthweight                                               1.6495      2.865      0.576      0.565      -3.966       7.265
# Adult.smoking                                                -0.5106      0.841     -0.607      0.544      -2.159       1.138
# =============================================================================================================================
# """

# %%
model_predictions_prob = logr_2008_results.predict(X)
model_predictions_binary = np.where(model_predictions_prob>0.5,1,0)
correct = (model_predictions_binary == y_2008_binary).sum()
correct/total
# Out:
# 0.8462528144097781

# %% [markdown]
# ### Alternate Model 2: Forwards (Automated) Selection -
# #### This Model was Selected as Best Performing (Explanation Below)
# Alternate Model 2 was developed by looping through all the possible columns and building the features one by one based off of the highest accuracy:

# %%
X_all_cols = ['Less Than High School Diploma', 'At Least High School Diploma',
       "At Least Bachelors's Degree", 'Graduate Degree', 'School Enrollment',
       'Median Earnings 2010', 'White (Not Latino) Population',
       'African American Population', 'Native American Population',
       'Asian American Population', 'Other Race or Races', 'Latino Population',
       'Children Under 6 Living in Poverty',
       'Adults 65 and Older Living in Poverty', 'Total Population',
       'Preschool.Enrollment.Ratio.enrolled.ages.3.and.4',
       'Poverty.Rate.below.federal.poverty.threshold', 'Gini.Coefficient',
       'Child.Poverty.living.in.families.below.the.poverty.line',
       'Management.professional.and.related.occupations',
       'Service.occupations', 'Sales.and.office.occupations',
       'Farming.fishing.and.forestry.occupations',
       'Construction.extraction.maintenance.and.repair.occupations',
       'Production.transportation.and.material.moving.occupations',
       'White_Asian', 'SIRE_homogeneity', 'median_age', 'Low.birthweight',
       'Teen.births', 'Children.in.single.parent.households', 'Adult.smoking',
       'Adult.obesity', 'Diabetes', 'Sexually.transmitted.infections',
       'HIV.prevalence.rate', 'Uninsured', 'Unemployment', 'Violent.crime',
       'Injury.deaths']

# %% [markdown]
# The for loop starts with checking one feature at a time, and based off of the highest accuracy, the best feature is added to the list of input features. The while loop repeats this until the features reaches the selected length of 10. The while loop adds the accuracy to a dictionary called results so at each step so that an optimal number of features can be selected.

# %%
X_current_cols = []
accuracy = 0
results = {}

while len(X_current_cols)<10:
    
    for i in range(len(X_all_cols)):
        
        if X_all_cols[i] not in X_current_cols:
            
            X_cols = X_current_cols + [X_all_cols[i]]
            X = sm.add_constant(df.loc[:,X_cols])
            logr_2008 = sm.Logit(y_2008,X)
            logr_2008_results = logr_2008.fit()
            
            model_predictions_prob = logr_2008_results.predict(X)
            model_predictions_binary = np.where(model_predictions_prob>0.5,1,0)
            correct = (model_predictions_binary == y_2008_binary).sum()
            
            if correct/total > accuracy:
                accuracy = correct/total
                best_col = [X_all_cols[i]]
                
    if X_all_cols[i] not in X_current_cols:
        X_current_cols += best_col
        results[len(X_current_cols)] = accuracy
# Out:
# C:\Users\rache\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# Optimization terminated successfully.
#          Current function value: 0.669547
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669581
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.662899
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659679
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.668531
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669170
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660252
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.662709
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669136
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.661672
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.669239
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669763
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669486
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.670004
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.663780
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665168
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.668810
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.667151
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669350
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.668912
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.664704
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.667647
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.665346
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.661030
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669383
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.661806
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.667196
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.667899
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669303
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.668663
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660062
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.668813
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669432
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669027
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659718
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.662402
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663373
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.663100
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.665252
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.666622
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.653910
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.653997
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.652857
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650430
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.657675
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.658808
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659367
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660197
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.655497
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.659975
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.657593
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660005
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659251
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.657165
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.657045
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660049
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659957
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659741
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.658440
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.658090
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.658237
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.654259
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.651819
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660065
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.655497
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.656969
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.660249
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659750
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.648642
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.657672
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659302
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.658579
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.657400
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.658031
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.658123
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.638597
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.657133
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659607
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.656708
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649617
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649591
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650208
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650271
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650387
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649146
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650186
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650160
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650430
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.647959
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649911
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650310
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650041
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649454
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650034
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650430
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649989
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649116
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.647356
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650158
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.647975
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.647154
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.648482
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650160
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.643505
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649868
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650423
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.646510
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.645592
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650344
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650230
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650362
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.648452
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649526
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636318
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645397
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.650121
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.650037
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.636175
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636247
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635586
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636267
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.633623
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636272
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636134
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636308
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636317
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636111
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.634046
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635738
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636195
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636248
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.633458
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635661
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.633732
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.633703
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632476
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636311
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635961
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635954
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635631
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636308
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632485
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635449
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636317
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635964
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632852
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635830
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636244
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636317
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635950
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636071
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.631726
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636198
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636098
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632471
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632486
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632037
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632335
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.631179
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632101
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632373
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632388
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632196
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.631497
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.630907
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632430
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632152
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632390
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.630895
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632062
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.630791
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.629985
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.629369
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632453
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.631815
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632190
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.631775
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632388
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.631903
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632483
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632203
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628442
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.631942
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632422
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632486
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.631873
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.631944
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628056
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.631871
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632352
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628298
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628272
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628431
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628369
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628241
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628308
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628357
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627880
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628119
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628441
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628395
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628396
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627900
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628418
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628391
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628436
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628420
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627523
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626785
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628443
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628341
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628309
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628304
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627880
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628062
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627658
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626744
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628437
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627447
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627423
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628416
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628304
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626423
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628416
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.628415
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627416
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627407
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627361
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627380
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627250
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627409
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627335
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626967
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627137
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627053
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627267
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627421
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626983
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627390
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627215
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627411
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627252
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626356
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626077
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627423
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627223
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627310
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627081
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626967
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626756
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627113
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626060
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627306
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627172
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627422
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627226
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.624802
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627397
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627422
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626160
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626179
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626294
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626353
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626276
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626346
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626059
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625888
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626059
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625742
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626249
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626356
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625870
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626318
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626242
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626320
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626242
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625448
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626278
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626312
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625927
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626352
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625888
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625197
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626050
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.624768
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626321
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626080
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626342
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626080
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.624471
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626343
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626345
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625656
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625679
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625826
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625865
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625704
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625844
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625495
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625654
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625584
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625157
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625749
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625869
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625829
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625719
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625850
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625751
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.624880
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625705
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625860
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625508
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625869
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625654
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.624717
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625610
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.624398
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625832
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625661
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625851
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625706
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.624160
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625870
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625846
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625481
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625505
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625632
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625695
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625679
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625367
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625455
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625438
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625033
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625650
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625704
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625657
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625665
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625704
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625659
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.624872
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625578
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625664
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625447
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625701
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625455
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.624406
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625450
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.624278
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625658
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625437
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625700
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625533
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.623933
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625704
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625686
#          Iterations 5

# %%
results
# Out:
# {1: 0.7664844001286587,
#  2: 0.7973624959794146,
#  3: 0.8105500160823416,
#  4: 0.8144097780636861,
#  5: 0.8201994210357028,
#  6: 0.826632357671277,
#  7: 0.8324220006432936,
#  8: 0.8378899967835317,
#  9: 0.8411064651013187,
#  10: 0.8427146992602123}

# %% [markdown]
# From the results we can see that the model reaches 83% accuracy by feature 7 so this was selected as optimal.

# %%
X_current_cols = X_current_cols[0:7]
X_current_cols
# Out:
# ['White (Not Latino) Population',
#  'Graduate Degree',
#  'Uninsured',
#  'SIRE_homogeneity',
#  'Children.in.single.parent.households',
#  'Diabetes',
#  'Management.professional.and.related.occupations']

# %%
X = sm.add_constant(df.loc[:,X_current_cols])
logr_2008 = sm.Logit(y_2008,X)
logr_2008_results = logr_2008.fit()
logr_2008_results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.626356
#          Iterations 5
# C:\Users\rache\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:     Republicans 08 pct   No. Observations:                 3109
# Model:                          Logit   Df Residuals:                     3101
# Method:                           MLE   Df Model:                            7
# Date:                Thu, 24 Oct 2019   Pseudo R-squ.:                 -0.1137
# Time:                        17:05:04   Log-Likelihood:                -1947.3
# converged:                       True   LL-Null:                       -1748.6
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                              -1.4442      0.577     -2.503      0.012      -2.575      -0.313
# White (Not Latino) Population                       0.0249      0.004      5.740      0.000       0.016       0.033
# Graduate Degree                                    -0.0573      0.015     -3.876      0.000      -0.086      -0.028
# Uninsured                                           5.1737      0.895      5.782      0.000       3.420       6.927
# SIRE_homogeneity                                   -1.5875      0.427     -3.719      0.000      -2.424      -0.751
# Children.in.single.parent.households               -1.9298      0.546     -3.534      0.000      -3.000      -0.860
# Diabetes                                            4.2845      2.174      1.971      0.049       0.024       8.545
# Management.professional.and.related.occupations     0.0179      0.009      1.983      0.047       0.000       0.036
# ===================================================================================================================
# """

# %%
model_predictions_prob = logr_2008_results.predict(X)
model_predictions_binary = np.where(model_predictions_prob>0.5,1,0)
correct = (model_predictions_binary == y_2008_binary).sum()

# %%
correct/total
# Out:
# 0.8324220006432936

# %%
pd.Series([variance_inflation_factor(X.values, i) 
               for i in range(X.shape[1])], 
              index=X.columns)
# Out:
# const                                              232.646367
# White (Not Latino) Population                        4.437361
# Graduate Degree                                      2.240136
# Uninsured                                            1.603675
# SIRE_homogeneity                                     3.991506
# Children.in.single.parent.households                 2.214237
# Diabetes                                             1.688353
# Management.professional.and.related.occupations      2.199935
# dtype: float64

# %% [markdown]
# ### Comparison of Logistic Regression Models:
# Models were compared on the basis of the key model selection parameters listed above:
# * An accuracy equivalent to or slightly lower than 0.84:
#     * **Alt 1: 0.846**
#     * **Alt 2: 0.832**
# * Fewer input variables (ideally 15-20)
#     * **Alt 1: 20 Inputs**
#     * **Alt 2: 7 Inputs**
# * VIFs lower than the baseline model
#     * **Comparable VIFs**
# * Statistically significant p-vales (below 0.05)
#     * **Alt 1: 50% of p-values higher than 0.05**
#     * **Alt 2: p-values below 0.05**
# * Standard errors which are significantly lower than coefficients
#     * **Alt 1 has some std errors larger than coefficients**

# %% [markdown]
# **ALTERNATE MODEL 2** was selected as it was the only model which met the key parameters

# %% [markdown]
# ### Model Interpretation
#
# The selected model had the following inputs as independent variables:
#
# White (Not Latino) Population, Graduate Degree, Uninsured, SIRE_homogeneity, Children.in.single.parent.households, Diabetes, Management.professional.and.related.occupations
#
# A couple of these variables were moderately correlated with the republican vote share in the exploratory data analysis.
#
#
# Because the units vary, coefficients cannot be compared directly; however, the sign of the coefficient gives explanation into which way the feature influences the dependent variable (i.e. as graduate degrees increase, the republican vote share decreases).
#
# Units of some coefficients are inferred - such as White Population (in Percent).
#
# This coefficient can then be interpreted as: with every 1 year increase in percentage of white population, odds of republican a majority republican vote share increases by e^0.0249, or 1.025 times.

# %% [markdown]
# # 2012 and 2016 Linear Regression Fitting
# Using the model for linear regression selected above, 2012 and 2016 were also fitted to a linear regression model.

# %%
X_cols = ['Graduate Degree',
 'Children.in.single.parent.households',
 'Uninsured',
 'White (Not Latino) Population',
 'SIRE_homogeneity',
 'Unemployment',
 'Teen.births',
 'Service.occupations',
 'Diabetes',
 'Production.transportation.and.material.moving.occupations',
 'median_age',
 'Native American Population',
 'Total Population',
 'Sexually.transmitted.infections',
 'Poverty.Rate.below.federal.poverty.threshold',
 'Other Race or Races',
 'Sales.and.office.occupations',
 'School Enrollment',
 'Low.birthweight',
 'Adult.smoking']

# %%
X = sm.add_constant(df.loc[:,X_cols])
y_2012 = df['Republicans 12 pct']
y_2016 = df['Republicans 16 pct']

# %% [markdown]
# 2012 Linear Regression Model:

# %%
lr_2012 = sm.OLS(y_2012,X)
lr_2012_results = lr_2012.fit()
lr_2012_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Republicans 12 pct   R-squared:                       0.712
# Model:                            OLS   Adj. R-squared:                  0.710
# Method:                 Least Squares   F-statistic:                     381.8
# Date:                Thu, 24 Oct 2019   Prob (F-statistic):               0.00
# Time:                        17:22:21   Log-Likelihood:                -10897.
# No. Observations:                3109   AIC:                         2.184e+04
# Df Residuals:                    3088   BIC:                         2.196e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# =============================================================================================================================
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# const                                                        54.5592      4.111     13.271      0.000      46.498      62.620
# Graduate Degree                                              -1.1186      0.057    -19.531      0.000      -1.231      -1.006
# Children.in.single.parent.households                        -32.2536      2.567    -12.566      0.000     -37.286     -27.221
# Uninsured                                                   101.3141      4.217     24.027      0.000      93.046     109.582
# White (Not Latino) Population                                 0.6521      0.019     35.117      0.000       0.616       0.689
# SIRE_homogeneity                                            -26.8657      1.792    -14.996      0.000     -30.379     -23.353
# Unemployment                                                -77.8181      6.687    -11.638      0.000     -90.929     -64.707
# Teen.births                                                   0.1861      0.014     13.496      0.000       0.159       0.213
# Service.occupations                                          -0.5405      0.052    -10.413      0.000      -0.642      -0.439
# Diabetes                                                    133.7839     10.168     13.157      0.000     113.846     153.722
# Production.transportation.and.material.moving.occupations    -0.5014      0.037    -13.434      0.000      -0.575      -0.428
# median_age                                                   -0.5613      0.042    -13.331      0.000      -0.644      -0.479
# Native American Population                                   -0.0629      0.029     -2.194      0.028      -0.119      -0.007
# Total Population                                          -2.562e-06   5.19e-07     -4.933      0.000   -3.58e-06   -1.54e-06
# Sexually.transmitted.infections                              -0.0063      0.001     -6.381      0.000      -0.008      -0.004
# Poverty.Rate.below.federal.poverty.threshold                 -0.2234      0.041     -5.384      0.000      -0.305      -0.142
# Other Race or Races                                          -0.4601      0.109     -4.207      0.000      -0.675      -0.246
# Sales.and.office.occupations                                 -0.2005      0.050     -3.987      0.000      -0.299      -0.102
# School Enrollment                                             0.0907      0.034      2.682      0.007       0.024       0.157
# Low.birthweight                                              42.9393     11.108      3.866      0.000      21.160      64.718
# Adult.smoking                                               -11.9271      3.246     -3.674      0.000     -18.292      -5.562
# ==============================================================================
# Omnibus:                       21.799   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.536
# Skew:                          -0.184   Prob(JB):                     1.28e-05
# Kurtosis:                       3.196   Cond. No.                     2.70e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.7e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# 2016 Linear Regression Model:

# %%
lr_2016 = sm.OLS(y_2016,X)
lr_2016_results = lr_2016.fit()
lr_2016_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Republicans 16 pct   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     633.0
# Date:                Thu, 24 Oct 2019   Prob (F-statistic):               0.00
# Time:                        17:22:27   Log-Likelihood:                -10516.
# No. Observations:                3109   AIC:                         2.107e+04
# Df Residuals:                    3088   BIC:                         2.120e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# =============================================================================================================================
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# const                                                        48.4522      3.637     13.323      0.000      41.321      55.583
# Graduate Degree                                              -1.6387      0.051    -32.345      0.000      -1.738      -1.539
# Children.in.single.parent.households                        -27.2497      2.271    -12.002      0.000     -31.702     -22.798
# Uninsured                                                    75.1413      3.730     20.144      0.000      67.827      82.455
# White (Not Latino) Population                                 0.6937      0.016     42.226      0.000       0.661       0.726
# SIRE_homogeneity                                            -23.1867      1.585    -14.630      0.000     -26.294     -20.079
# Unemployment                                                -83.8357      5.915    -14.173      0.000     -95.434     -72.238
# Teen.births                                                   0.1755      0.012     14.386      0.000       0.152       0.199
# Service.occupations                                          -0.3641      0.046     -7.928      0.000      -0.454      -0.274
# Diabetes                                                    108.2792      8.995     12.037      0.000      90.642     125.917
# Production.transportation.and.material.moving.occupations    -0.3126      0.033     -9.466      0.000      -0.377      -0.248
# median_age                                                   -0.3753      0.037    -10.075      0.000      -0.448      -0.302
# Native American Population                                    0.0215      0.025      0.846      0.397      -0.028       0.071
# Total Population                                          -2.807e-06    4.6e-07     -6.109      0.000   -3.71e-06   -1.91e-06
# Sexually.transmitted.infections                              -0.0079      0.001     -8.998      0.000      -0.010      -0.006
# Poverty.Rate.below.federal.poverty.threshold                 -0.1168      0.037     -3.183      0.001      -0.189      -0.045
# Other Race or Races                                          -0.3056      0.097     -3.159      0.002      -0.495      -0.116
# Sales.and.office.occupations                                 -0.2756      0.044     -6.197      0.000      -0.363      -0.188
# School Enrollment                                             0.1056      0.030      3.530      0.000       0.047       0.164
# Low.birthweight                                              31.8462      9.826      3.241      0.001      12.580      51.113
# Adult.smoking                                                 0.9882      2.872      0.344      0.731      -4.642       6.619
# ==============================================================================
# Omnibus:                      118.878   Durbin-Watson:                   1.804
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              167.258
# Skew:                          -0.380   Prob(JB):                     4.79e-37
# Kurtosis:                       3.846   Cond. No.                     2.70e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.7e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Performance Comparison:
# Based off of the adjusted R squared alone, the performance of the fitted models appear to get better from 2008 (0.69) to 2012 (0.71) to 2016 (0.80), however some features appear to become less statstically significant in 2016 such as Native American population and Adult Smoking. This seems to indicate that the selected features become more predictive for republican vote share as the years pass.
#
# For future analysis, fitting a new model on the 2016 data may result in better performance than the 2008 model with even fewer features.

# %% [markdown]
# # 2012 and 2016 Logistic Regression Fitting
# Using the model for logistic regression selected above, 2012 and 2016 were also fitted to a logistic regression model.

# %%
X_cols = ['White (Not Latino) Population',
 'Graduate Degree',
 'Uninsured',
 'SIRE_homogeneity',
 'Children.in.single.parent.households',
 'Diabetes',
 'Management.professional.and.related.occupations']

# %%
X = sm.add_constant(df.loc[:,X_cols])
y_2012 = df['Republicans 12 pct']/100
y_2016 = df['Republicans 16 pct']/100
y_2012_binary = np.where(y_2012>0.5,1,0)
y_2016_binary = np.where(y_2016>0.5,1,0)

total = len(y_2008)
# Out:
# C:\Users\rache\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %% [markdown]
# 2012 Logistic Regression Model:

# %%
logr_2012 = sm.Logit(y_2012,X)
logr_2012_results = logr_2012.fit()
logr_2012_results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.595013
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:     Republicans 12 pct   No. Observations:                 3109
# Model:                          Logit   Df Residuals:                     3101
# Method:                           MLE   Df Model:                            7
# Date:                Thu, 24 Oct 2019   Pseudo R-squ.:                 -0.2042
# Time:                        17:30:57   Log-Likelihood:                -1849.9
# converged:                       True   LL-Null:                       -1536.2
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                              -1.7186      0.591     -2.908      0.004      -2.877      -0.560
# White (Not Latino) Population                       0.0278      0.004      6.338      0.000       0.019       0.036
# Graduate Degree                                    -0.0620      0.015     -4.106      0.000      -0.092      -0.032
# Uninsured                                           5.9150      0.918      6.440      0.000       4.115       7.715
# SIRE_homogeneity                                   -1.4387      0.432     -3.329      0.001      -2.286      -0.592
# Children.in.single.parent.households               -2.1450      0.558     -3.846      0.000      -3.238      -1.052
# Diabetes                                            4.0641      2.215      1.835      0.066      -0.277       8.405
# Management.professional.and.related.occupations     0.0200      0.009      2.136      0.033       0.002       0.038
# ===================================================================================================================
# """

# %%
model_predictions_prob = logr_2012_results.predict(X)
model_predictions_binary = np.where(model_predictions_prob>0.5,1,0)
correct = (model_predictions_binary == y_2012_binary).sum()
correct/total
# Out:
# 0.8774525570923126

# %%
logr_2016 = sm.Logit(y_2016,X)
logr_2016_results = logr_2016.fit()
logr_2016_results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.517328
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:     Republicans 16 pct   No. Observations:                 3109
# Model:                          Logit   Df Residuals:                     3101
# Method:                           MLE   Df Model:                            7
# Date:                Thu, 24 Oct 2019   Pseudo R-squ.:                 -0.3795
# Time:                        17:31:18   Log-Likelihood:                -1608.4
# converged:                       True   LL-Null:                       -1165.9
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                              -1.7235      0.622     -2.773      0.006      -2.942      -0.505
# White (Not Latino) Population                       0.0306      0.004      7.007      0.000       0.022       0.039
# Graduate Degree                                    -0.0947      0.016     -5.871      0.000      -0.126      -0.063
# Uninsured                                           5.4123      0.963      5.622      0.000       3.525       7.299
# SIRE_homogeneity                                   -1.0014      0.434     -2.306      0.021      -1.852      -0.150
# Children.in.single.parent.households               -1.9363      0.583     -3.320      0.001      -3.079      -0.793
# Diabetes                                            4.3947      2.319      1.895      0.058      -0.151       8.940
# Management.professional.and.related.occupations     0.0185      0.010      1.848      0.065      -0.001       0.038
# ===================================================================================================================
# """

# %%
model_predictions_prob = logr_2016_results.predict(X)
model_predictions_binary = np.where(model_predictions_prob>0.5,1,0)
correct = (model_predictions_binary == y_2016_binary).sum()
correct/total
# Out:
# 0.9266645223544548

# %% [markdown]
# ## Performance Comparison:
# Based off of the accuracy alone, the model performance appears to get better from 2008 (0.83) to 2012 (0.87) to 2016 (0.93), however some features appear to become less statstically significant in 2012 and 2016 such as Diabetes and Management occupations. This seems to indicate that the selected features become more predictive for republican vote share as the years pass.
#
# Again, for future analysis, fitting a new model on the 2012, 2016 data may result in better performance than the 2008 model with even fewer features.
